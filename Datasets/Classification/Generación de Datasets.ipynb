# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Ruido con una distribución Uniforme

# %%
X,Y= make_blobs(n_samples=200, centers=2, n_features=2, cluster_std=4, random_state=42)
random_noise=np.random.uniform(low=-20, high=20, size=(200,2))
X+=random_noise
plt.scatter(X[:,0], X[:,1],c=Y)

# %%
df= pd.DataFrame(X, columns=["Feature 1", "Feature 2"])
df["Target"]= Y
df.to_csv("Uniform_Noise.csv")
df
# Out:
#      Feature 1  Feature 2  Target
# 0     0.197323   0.286793       1
# 1     0.276127   0.664153       1
# 2     0.513897   0.672063       1
# 3     0.375591   0.719687       0
# 4     0.258374   0.580869       1
# ..         ...        ...     ...
# 195   0.383061   0.714514       0
# 196   0.365331   0.799633       1
# 197   0.095157   0.175736       0
# 198   0.787625   0.398010       1
# 199   0.550679   0.367773       0
#
# [200 rows x 3 columns]

# %% [markdown]
# # Ruido con una distribución Gaussiana

# %%
X, Y = make_blobs(n_samples=200, centers=2, n_features=2, cluster_std=4, random_state=42)
random_noise = np.random.normal(loc=0, scale=18, size=(200, 2)) #media 0 y desviación standard 18
X += random_noise
plt.scatter(X[:,0], X[:,1], c=Y)

# %%
df= pd.DataFrame(X, columns=["Feature 1", "Feature 2"])
df["Target"]= Y
df.to_csv("Gauss_Noise.csv")
df
# Out:
#      Feature 1  Feature 2  Target
# 0     0.517606   0.475244       1
# 1     0.739287   0.342235       1
# 2     0.497136   0.544859       1
# 3     0.465907   0.924069       0
# 4     0.596852   0.071573       1
# ..         ...        ...     ...
# 195   0.356204   0.668637       0
# 196   0.481528   0.545663       1
# 197   0.117351   0.663103       0
# 198   0.536889   0.761474       1
# 199   0.400245   0.146434       0
#
# [200 rows x 3 columns]

# %% [markdown]
# # Ruido exponencial

# %%
X, Y = make_blobs(n_samples=200, centers=2, n_features=2, cluster_std=4, random_state=42)
random_noise = np.random.exponential(scale=14, size=(200, 2))#Con tasa media de 1/14
X += random_noise
plt.scatter(X[:,0], X[:,1], c=Y)
plt.show()

# %%
df= pd.DataFrame(X, columns=["Feature 1", "Feature 2"])
df["Target"]= Y
df.to_csv("Exponential_Noise.csv")
df
# Out:
#      Feature 1  Feature 2  Target
# 0     0.101958   0.046656       1
# 1     0.641003   0.073743       1
# 2     0.201643   0.135687       1
# 3     0.037530   0.254383       0
# 4     0.713271   0.093078       1
# ..         ...        ...     ...
# 195   0.313915   0.181326       0
# 196   0.298860   0.125050       1
# 197   0.178283   0.291979       0
# 198   0.216180   0.352892       1
# 199   0.333069   0.274628       0
#
# [200 rows x 3 columns]

# %% [markdown]
# # Ruido gamma

# %%
X, Y = make_blobs(n_samples=200, centers=2, n_features=2, cluster_std=4, random_state=42)
random_noise = np.random.gamma(35, 3, size=(200, 2)) #Forma 10 y escala 1
X += random_noise

plt.scatter(X[:,0], X[:,1], c=Y)
plt.show()

# %%
df= pd.DataFrame(X, columns=["Feature 1", "Feature 2"])
df["Target"]= Y
df.to_csv("Gamma_Noise.csv")
df
# Out:
#      Feature 1  Feature 2  Target
# 0     0.273746   0.151618       1
# 1     0.304686   0.440060       1
# 2     0.333892   0.454674       1
# 3     0.342556   0.552871       0
# 4     0.612823   0.222977       1
# ..         ...        ...     ...
# 195   0.104276   0.642762       0
# 196   0.260737   0.384257       1
# 197   0.800198   0.289669       0
# 198   0.561403   0.268255       1
# 199   0.464107   0.618835       0
#
# [200 rows x 3 columns]
